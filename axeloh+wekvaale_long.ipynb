# %% [markdown]
# # Contents
# 1. Exploratory Data Analysis
# 2. Data Preprocessing
# 3. Model choice and training
# 4. Prediction results
# 5. Interpretation
# 6. Conclusion

# %% [markdown]
# import pandas as pd

# %%
df = pd.read_csv("data/challenge3_train.csv")
df.head(10)
# Out:
#    id  target   f0   f1   f2   f3      f4   f5   f6       f7  ...  f21  \
# 0   0       1  0.0  5.0  0.0  4.0  3598.0    M  3.0  -7.2430  ...  3.0
# 1   1       0  NaN  5.0  4.0  NaN  2072.0  NaN  4.0  -1.6662  ...  3.0
# 2   2       0  1.0  1.0  4.0  2.0   862.0    M  3.0  -0.1200  ...  NaN
# 3   3       0  NaN  NaN  2.0  1.0   409.0    F  5.0 -16.2169  ...  5.0
# 4   4       1  NaN  5.0  0.0  3.0   222.0  NaN  5.0  -8.1088  ...  5.0
# 5   5       0  NaN  2.0  2.0  2.0   190.0    F  NaN -12.5919  ...  2.0
# 6   6       1  NaN  2.0  4.0  4.0  2004.0    M  1.0  -7.3340  ...  1.0
# 7   7       1  NaN  2.0  0.0  4.0  2422.0    M  4.0  -2.0356  ...  4.0
# 8   8       1  0.0  5.0  2.0  3.0     NaN    F  3.0  -3.6158  ...  NaN
# 9   9       1  NaN  NaN  0.0  5.0  2583.0    M  1.0 -12.8912  ...  1.0
#
#        f22  f23  f24  f25  f26  f27 f28  f29       f30
# 0  14.2364  0.0  NaN  4.0  1.0  5.0  PS  2.0  0.834041
# 1      NaN  2.0  3.0  NaN  1.0  5.0  DT  5.0  0.686021
# ...

# %%
df.isna().sum()
# Out:
# id            0
# target        0
# f0        32976
# f1         7148
# f2         7115
# f3         6648
# f4         8911
# f5         6208
# f6         6824
# f7         8862
# f8          145
# f9         6865
# f10         160
# f11       11617
# f12        1513
# f13        9977
# f14        9868
# f15        9570
# f16        9762
# f17       10898
# f18        9408
# f19        5342
# f20        1512
# f21        7283
# f22       13112
# f23        7808
# f24       10104
# f25        8246
# f26        9452
# f27        7911
# f28        1428
# f29        7404
# f30        2696
# dtype: int64

# %%
df.describe()
# Out:
#                  id        target            f0            f1            f2  \
# count  50000.000000  50000.000000  17024.000000  42852.000000  42885.000000
# mean   24999.500000      0.434240      0.186443      3.205778      1.662749
# std    14433.901067      0.495662      0.389475      1.331336      1.761244
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%    12499.750000      0.000000      0.000000      2.000000      0.000000
# 50%    24999.500000      0.000000      0.000000      3.000000      2.000000
# 75%    37499.250000      1.000000      0.000000      4.000000      3.000000
# max    49999.000000      1.000000      1.000000      5.000000      5.000000
#
#                  f3            f4            f6            f7            f8  \
# count  43352.000000  41089.000000  43176.000000  41138.000000  49855.000000
# mean       3.304484   1188.594003      3.058482     -4.792173     14.223701
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      50000 non-null  int64
#  1   target  50000 non-null  int64
#  2   f0      17024 non-null  float64
#  3   f1      42852 non-null  float64
#  4   f2      42885 non-null  float64
#  5   f3      43352 non-null  float64
#  6   f4      41089 non-null  float64
#  7   f5      43792 non-null  object
#  8   f6      43176 non-null  float64
#  9   f7      41138 non-null  float64
#  10  f8      49855 non-null  float64
#  11  f9      43135 non-null  float64
#  12  f10     49840 non-null  float64
#  13  f11     38383 non-null  float64
#  14  f12     48487 non-null  object
#  15  f13     40023 non-null  float64
#  16  f14     40132 non-null  float64
#  17  f15     40430 non-null  object
#  18  f16     40238 non-null  float64
#  19  f17     39102 non-null  float64
# ...
